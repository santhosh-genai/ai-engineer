# %% [markdown]
# # Defect Trends Visualization
#
# This notebook demonstrates how to create a line plot showing defect trends over time using matplotlib.

# %% [markdown]
# ## Import Required Libraries
# First, let's import matplotlib for creating our visualization:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Prepare the Data
# Define the weeks and corresponding defect counts:

# %% [markdown]
# ## Create the Plot
# Now let's create the line plot with customized styling:

# %%
Weeks = [1, 2, 3, 4, 5, 6]
Defects = [5, 8, 6, 10, 7, 4]

plt.plot(Weeks, Defects, marker='>', linestyle=':', color='orange')
plt.grid(True)
plt.title('Defect Trends Over Time')
plt.xlabel('Week Number')
plt.ylabel('Number of Defects')
plt.show()
